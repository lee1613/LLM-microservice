# %% [markdown]
# # LLM Exploration Notebook
#
# Use this notebook to explore LLM APIs, prototype data processing, and experiment with new features.

# %%
import os
from dotenv import load_dotenv

load_dotenv() # Load variables from .env

# %%
# Example check for API keys
openai_api_key = os.getenv('OPENAI_API_KEY')
print(f"API Key found: {openai_api_key is not None}")
